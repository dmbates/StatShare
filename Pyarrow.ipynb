# %% [markdown]
# # Read Arrow file in Python

# %%
import pyarrow.feather as fea
import polars as pl
tbl = fea.read_table("ncvoter_Statewide.arrow")
tbl
# Out:
# pyarrow.Table
# county_id: int8 not null
# county_desc: dictionary<values=string, indices=int8, ordered=0> not null
# voter_reg_num: int32 not null
# ncid: string not null
# last_name: dictionary<values=string, indices=int32, ordered=0> not null
# first_name: dictionary<values=string, indices=int32, ordered=0>
# middle_name: dictionary<values=string, indices=int32, ordered=0>
# name_suffix_lbl: dictionary<values=string, indices=int8, ordered=0>
# status_cd: dictionary<values=string, indices=int8, ordered=0> not null
# voter_status_desc: dictionary<values=string, indices=int8, ordered=0> not null
# reason_cd: dictionary<values=string, indices=int8, ordered=0>
# voter_status_reason_desc: dictionary<values=string, indices=int8, ordered=0>
# res_street_address: string not null
# res_city_desc: dictionary<values=string, indices=int16, ordered=0>
# state_cd: dictionary<values=string, indices=int8, ordered=0>
# zip_code: int32
# mail_addr1: string
# ...
